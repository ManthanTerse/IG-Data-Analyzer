# %% [markdown]
# # IG-Data-Viz

# %%
with open("finaldata.txt" , encoding = 'utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]

# %%
chunks[0]
# Out:
# 'techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'

# %%
chunks[1]
# Out:
# 'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'

# %%
def parse_chunk(chunk):
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_posts = int(sep_chunk[1].split("post")[0].replace(",",""))
    
        no_of_followers = float(sep_chunk[2].split("follower")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000)
        elif("M" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000000)
        else:
            no_of_followers = int(no_of_followers)

        no_of_following = float(sep_chunk[3].split("following")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000)
        elif("M" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000000)
        else:
            no_of_following = int(no_of_following)
        name = sep_chunk[4]
        if(len(sep_chunk)>5):
            role = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            role = "Unknown"
            bio = ""
        return {"username" : username , "no_of_posts" : no_of_posts ,
        "no_of_followers" : no_of_followers , "no_of_following" : no_of_following , 
        "Name" : name , "Category" : role , "Bio" : bio}

# %%
all_chunks=[]
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

# %%
import json
s = json.dumps(all_chunks, indent=5)

with open("data.json" , "w") as f:
    f.write(s)

# %% [markdown]
# # Who has the max post :

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post)
# Out:
# {'username': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'Name': 'Startup Hub Bangalore', 'Category': 'Media', 'Bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %%
print(chunk_with_max_post['username']) #ID who has maximum posts
# Out:
# startuphub_blr

# %% [markdown]
# # Who has maximum followers :

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_followers']):
        max = chunk['no_of_followers']
        chunk_with_max_followers = chunk
print(chunk_with_max_followers)
# Out:
# {'username': '_anujsinghal', 'no_of_posts': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'Name': 'Anuj Singhal', 'Category': 'Digital creator', 'Bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %%
print(chunk_with_max_followers['username'])
# Out:
# _anujsinghal

# %% [markdown]
# # Who follows maximum people :

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_following']):
        max = chunk['no_of_following']
        chunk_with_max_following = chunk
print(chunk_with_max_following)
# Out:
# {'username': 'bangalore_tech_bro', 'no_of_posts': 402, 'no_of_followers': 12500, 'no_of_following': 890, 'Name': 'Rahul | HSR Hustler', 'Category': 'Entrepreneur', 'Bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %%
print(chunk_with_max_following['username'])
# Out:
# bangalore_tech_bro

# %% [markdown]
# # How many  categories?

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['Category'])

print(categories)
# Out:
# {'Lifestyle', 'Full-stack Dev', 'Nonprofit organization', 'Education', 'Entrepreneur', 'Founder', 'Engineer', 'Tech Creator', 'Blog', 'Food & Drink', 'Data Science', 'Writer', 'Data Scientist', 'Developer', 'Community', 'Comedy', 'Tech', 'Educator', 'Product Manager', 'Blogger', 'Personal Blog', 'Public Figure', 'Investor', 'Coder', 'Cafe Explorer', 'Recruiter', 'Digital creator', 'Media', 'Cafe Nerd', 'Artist + Coder', 'Backend Developer', 'Software Engineer', 'Design', 'Frontend Dev'}

# %%
print(len(categories))
# Out:
# 34
